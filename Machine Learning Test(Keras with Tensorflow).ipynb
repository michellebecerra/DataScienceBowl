# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv3D, Activation, MaxPooling3D
from keras.layers.core import Dense, Dropout, Flatten

IMG_SIZE_PX = 50
SLICE_COUNT = 20

n_classes = 2
batch_size = 5

keep_rate = 0.8

def ShapeInputOuput(data):
    X = np.reshape(([a[0] for a in data]), (-1, IMG_SIZE_PX, IMG_SIZE_PX, SLICE_COUNT, 1))
    Y = np.array([a[1] for a in data])
    return X, Y

def buildCNN():
    model = Sequential()
    convLayer1 = Conv3D(32, [3,3,3], strides=[1,1,1], kernel_initializer='normal', activation='relu', padding='same', use_bias=True, input_shape=[IMG_SIZE_PX, IMG_SIZE_PX, SLICE_COUNT, 1])
    model.add(convLayer1)
    maxPoolLayer1 = MaxPooling3D([2,2,2], strides=[2,2,2], padding='same')
    model.add(maxPoolLayer1)
    convLayer2 = Conv3D(64, [3,3,3], strides=[1,1,1], kernel_initializer='normal', activation='relu', padding='same', use_bias=True)
    model.add(convLayer2)
    maxPoolLayer2 = MaxPooling3D([2,2,2], strides=[2,2,2], padding='same')
    model.add(maxPoolLayer2)
    model.add(Flatten())
    fcLayer = Dense(1024, kernel_initializer='normal', activation='relu', use_bias=True)
    model.add(fcLayer)
    dropoutLayer = Dropout(1 - keep_rate)
    model.add(dropoutLayer)
    #use softmax activation so that combined with binary_crossentropy loss you get Tensorflow's softmax_cross_entropy_with_logits
    outputLayer = Dense(2, kernel_initializer='normal', activation='softmax', use_bias=True)
    model.add(outputLayer)

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

model = buildCNN()

much_data = np.load('muchdata-50-50-20.npy')
# If you are working with the basic sample data, use maybe 2 instead of 100 here... you don't have enough data to really do this
train_data = much_data[:-2]
validation_data = much_data[-2:]

X, Y = ShapeInputOuput(train_data)
validation_data = ShapeInputOuput(validation_data)
#print(len(train_data))
#print (np.shape(X))
#print (np.shape(Y))
#print (len(validation_data))
model.fit(X, Y,  batch_size=1, epochs=10, validation_data=validation_data)
[X, Y] = np.transpose(validation_data)
#model.evaluate(X, Y)
# Out:
# Train on 17 samples, validate on 2 samples
# Epoch 1/10
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# C:\Users\caixin\Anaconda2\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# C:\Users\caixin\Anaconda2\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# C:\Users\caixin\Anaconda2\envs\tensorflow\lib\contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# ...
